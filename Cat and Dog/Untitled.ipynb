# %%
pip install tensorflow opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions

# load pretrained model
model = MobileNetV2(weights='imagenet')

def predict_image(img_path):
    img = cv2.imread(img_path)
    
    if img is None:
        print("Image not found ❌")
        return
    
    img = cv2.resize(img, (224, 224))
    img = np.array(img)
    img = preprocess_input(img)
    img = np.expand_dims(img, axis=0)

    preds = model.predict(img)
    decoded = decode_predictions(preds, top=3)[0]

    print("\nTop Predictions:")
    for i in decoded:
        print(i[1], ":", round(i[2]*100, 2), "%")

    # simple dog/cat check
    label = decoded[0][1]

    if "dog" in label or "retriever" in label or "hound" in label:
        print("\nResult: Dog 🐶")
    elif "cat" in label:
        print("\nResult: Cat 🐱")
    else:
        print("\nResult: Not sure 🤔")

# 🔥 YOUR IMAGE PATH
predict_image(r"C:\Users\Anupa\Desktop\Project Backup 2\Project Baackup\Final Project1\Cat and Dog\Data\data\train\dogs\dog.4.jpg")
# Out:
# ...
# 14536120/14536120 ━━━━━━━━━━━━━━━━━━━━ 74s 5us/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ...
# 35363/35363 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
#
# Top Predictions:
# whippet : 41.44 %
# Italian_greyhound : 13.44 %
# Staffordshire_bullterrier : 4.02 %
#
# Result: Not sure 🤔

# %%
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions

# load pretrained model
model = MobileNetV2(weights='imagenet')

def predict_image(img_path):
    img = cv2.imread(img_path)
    
    if img is None:
        print("❌ Image not found. Check path!")
        return
    
    img = cv2.resize(img, (224, 224))
    img = preprocess_input(img)
    img = np.expand_dims(img, axis=0)

    preds = model.predict(img)
    decoded = decode_predictions(preds, top=3)[0]

    print("\nTop Predictions:")
    for i in decoded:
        print(i[1], ":", round(i[2]*100, 2), "%")

    label = decoded[0][1]

    if "dog" in label or "retriever" in label or "hound" in label:
        print("\n✅ Result: Dog 🐶")
    elif "cat" in label:
        print("\n✅ Result: Cat 🐱")
    else:
        print("\n🤔 Result: Not sure")

# 🔥 YOUR IMAGE
predict_image(r"C:\Users\Anupa\Desktop\Project Backup 2\Project Baackup\Final Project1\Cat and Dog Image Classification\Dog\test\04de2de8a19aedea44e26c6bf06923f5.jpg")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Top Predictions:
# golden_retriever : 23.98 %
# clumber : 19.4 %
# English_setter : 12.43 %
#
# ✅ Result: Dog 🐶

# %%
import cv2
import numpy as np
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2, preprocess_input, decode_predictions

# 🔥 Your breed list
BREEDS = {
    "Dog": [
        'Local',
        'German Shepherd',
        'Retriever',
        'Rottweiler',
        'Doberman Pinscher',
        'Pomeranian',
        'Shih Tzu',
        'Beagle',
    ],
    "Cat": [
        'Local Cats',
        'Persian Cat',
        'Siamese Cat',
        'British Shorthair',
        'Bengal Cat',
    ],
}

# load pretrained model
model = MobileNetV2(weights='imagenet')

def predict_image(img_path):
    img = cv2.imread(img_path)
    
    if img is None:
        print("❌ Image not found. Check path!")
        return
    
    img = cv2.resize(img, (224, 224))
    img = preprocess_input(img)
    img = np.expand_dims(img, axis=0)

    preds = model.predict(img)
    decoded = decode_predictions(preds, top=3)[0]

    print("\nTop Predictions:")
    for i in decoded:
        print(i[1], ":", round(i[2]*100, 2), "%")

    label = decoded[0][1].lower()

    # 🔥 Detect Dog / Cat
    if any(word in label for word in ["dog", "retriever", "hound", "shepherd", "terrier"]):
        print("\n✅ Result: Dog 🐶")

        print("👉 Possible Breeds:")
        for b in BREEDS["Dog"]:
            print("-", b)

    elif "cat" in label:
        print("\n✅ Result: Cat 🐱")

        print("👉 Possible Breeds:")
        for b in BREEDS["Cat"]:
            print("-", b)

    else:
        print("\n🤔 Result: Not sure")

# 🔥 YOUR IMAGE
predict_image(r"C:\Users\Anupa\Desktop\Project Backup 2\Project Baackup\Final Project1\Cat and Dog\Data\data\train\cats/cat.14.jpg")
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000001B9384B6340> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
#
# Top Predictions:
# Egyptian_cat : 87.46 %
# tabby : 6.65 %
# tiger_cat : 1.45 %
#
# ✅ Result: Cat 🐱
# 👉 Possible Breeds:
# - Local Cats
# - Persian Cat
# - Siamese Cat
# - British Shorthair
# - Bengal Cat
